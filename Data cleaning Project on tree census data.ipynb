# %% [markdown]
# ### Street Tree Census
# * Street tree data from the TreesCount! 2015 Street Tree Census, conducted by volunteers and staff organized by NYC Parks & Recreation and partner organizations. Tree data collected includes tree species, diameter and perception of health.
# * collected data from https://data.cityofnewyork.us/Environment/2015-Street-Tree-Census-Tree-Data/uvpi-gqnh

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_columns",None)

# %%
tree_census = pd.read_csv("/Users/shashidharpattar/Downloads/2015_Street_Tree_Census_-_Tree_Data.csv")
tree_census
# Out:
#         tree_id  block_id  created_at  tree_dbh  stump_diam curb_loc status  \
# 0        180683    348711  08/27/2015         3           0   OnCurb  Alive
# 1        200540    315986  09/03/2015        21           0   OnCurb  Alive
# 2        204026    218365  09/05/2015         3           0   OnCurb  Alive
# 3        204337    217969  09/05/2015        10           0   OnCurb  Alive
# 4        189565    223043  08/30/2015        21           0   OnCurb  Alive
# ...         ...       ...         ...       ...         ...      ...    ...
# 683783   155433    217978  08/18/2015        25           0   OnCurb  Alive
# 683784   183795    348185  08/29/2015         7           0   OnCurb  Alive
# 683785   166161    401670  08/22/2015        12           0   OnCurb  Alive
# 683786   184028    504204  08/29/2015         9           0   OnCurb  Alive
# 683787   200607    306527  09/03/2015        23           0   OnCurb  Alive
#
# ...

# %%
tree_census.columns
# Out:
# Index(['tree_id', 'block_id', 'created_at', 'tree_dbh', 'stump_diam',
#        'curb_loc', 'status', 'health', 'spc_latin', 'spc_common', 'steward',
#        'guards', 'sidewalk', 'user_type', 'problems', 'root_stone',
#        'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
#        'brch_light', 'brch_shoe', 'brch_other', 'address', 'postcode',
#        'zip_city', 'community board', 'borocode', 'borough', 'cncldist',
#        'st_assem', 'st_senate', 'nta', 'nta_name', 'boro_ct', 'state',
#        'latitude', 'longitude', 'x_sp', 'y_sp', 'council district',
#        'census tract', 'bin', 'bbl'],
#       dtype='object')

# %%
tree_census_subset = tree_census[['tree_id',  'tree_dbh', 'stump_diam',
       'curb_loc', 'status', 'health', 'spc_latin',  'steward',
      'sidewalk',  'problems', 'root_stone',
       'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
       'brch_light', 'brch_shoe', 'brch_other']]
tree_census_subset
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683         3           0   OnCurb  Alive   Fair
# 1        200540        21           0   OnCurb  Alive   Fair
# 2        204026         3           0   OnCurb  Alive   Good
# 3        204337        10           0   OnCurb  Alive   Good
# 4        189565        21           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 683783   155433        25           0   OnCurb  Alive   Good
# 683784   183795         7           0   OnCurb  Alive   Good
# 683785   166161        12           0   OnCurb  Alive   Good
# 683786   184028         9           0   OnCurb  Alive   Good
# 683787   200607        23           0   OnCurb  Alive   Fair
#
#                                  spc_latin steward  sidewalk problems  \
# 0                              Acer rubrum    None  NoDamage     None
# 1                        Quercus palustris    None    Damage   Stones
# ...

# %% [markdown]
# ### Observations
# * creating a subset of data with the columns that are helpful and deleting the columns that are of least importance.

# %% [markdown]
# ### searching if there is any missing values.

# %%
tree_census_subset.isna().sum()
# Out:
# tree_id           0
# tree_dbh          0
# stump_diam        0
# curb_loc          0
# status            0
# health        31616
# spc_latin     31619
# steward       31615
# sidewalk      31616
# problems      31664
# root_stone        0
# root_grate        0
# root_other        0
# trunk_wire        0
# trnk_light        0
# trnk_other        0
# brch_light        0
# brch_shoe         0
# brch_other        0
# dtype: int64

# %%
tree_census_subset[tree_census_subset["health"].isna()]
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health spc_latin  \
# 37       211205         0          16          OnCurb  Stump    NaN       NaN
# 57       187807         0           0          OnCurb   Dead    NaN       NaN
# 196      208322        10           0          OnCurb   Dead    NaN       NaN
# 209      209058         6           0          OnCurb   Dead    NaN       NaN
# 239      203597         0          15          OnCurb  Stump    NaN       NaN
# ...         ...       ...         ...             ...    ...    ...       ...
# 683693   156162         3           0  OffsetFromCurb   Dead    NaN       NaN
# 683695   170888         0           5          OnCurb  Stump    NaN       NaN
# 683697   177922         0          17          OnCurb  Stump    NaN       NaN
# 683698   193791         3           0          OnCurb   Dead    NaN       NaN
# 683699   172660         0           4          OnCurb  Stump    NaN       NaN
#
# ...

# %%
tree_census_subset.dtypes
# Out:
# tree_id        int64
# tree_dbh       int64
# stump_diam     int64
# curb_loc      object
# status        object
# health        object
# spc_latin     object
# steward       object
# sidewalk      object
# problems      object
# root_stone    object
# root_grate    object
# root_other    object
# trunk_wire    object
# trnk_light    object
# trnk_other    object
# brch_light    object
# brch_shoe     object
# brch_other    object
# dtype: object

# %%
tree_census_subset.describe()
# Out:
#              tree_id       tree_dbh     stump_diam
# count  683788.000000  683788.000000  683788.000000
# mean   365205.011085      11.279787       0.432463
# std    208122.092902       8.723042       3.290241
# min         3.000000       0.000000       0.000000
# 25%    186582.750000       4.000000       0.000000
# 50%    366214.500000       9.000000       0.000000
# 75%    546170.250000      16.000000       0.000000
# max    722694.000000     450.000000     140.000000

# %% [markdown]
# ### Observations
# * since tree diameter(tree_dbh) maximum value is 450 inches which may be outlier.

# %%
tree_census_subset.hist(bins=50,figsize=(15,10))
# Out:
# array([[<AxesSubplot:title={'center':'tree_id'}>,
#         <AxesSubplot:title={'center':'tree_dbh'}>],
#        [<AxesSubplot:title={'center':'stump_diam'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
outlier_trees = tree_census_subset[tree_census_subset["tree_dbh"]>60]
outlier_trees
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health  \
# 2405     168583       425           0          OnCurb  Alive   Good
# 4887     139665        72           0  OffsetFromCurb  Alive   Good
# 6724     209349       122           0          OnCurb  Alive   Good
# 10083    215075       169           0          OnCurb  Alive   Good
# 25862    214532       177           0          OnCurb  Alive   Fair
# ...         ...       ...         ...             ...    ...    ...
# 667425   151958        66           0  OffsetFromCurb  Alive   Fair
# 673105   165324        79           0          OnCurb  Alive   Good
# 674016   184879       105           0          OnCurb  Alive   Fair
# 681736   179366       281           0          OnCurb  Alive   Fair
# 682788   183910       127           0          OnCurb   Dead    NaN
#
#                                  spc_latin steward  sidewalk problems  \
# 2405                       Quercus bicolor    1or2    Damage     None
# ...

# %%
outlier_trees.plot(kind="scatter",x="tree_id",y="tree_dbh",figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='tree_id', ylabel='tree_dbh'>

# %% [markdown]
# ### Observations
# * it can be seen that there are outliers present from plot.

# %%
outlier_trees = tree_census_subset[tree_census_subset["stump_diam"]>60]
outlier_trees
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health spc_latin  \
# 6466     166008         0          72   OnCurb  Stump    NaN       NaN
# 7042     206818         0         100   OnCurb  Stump    NaN       NaN
# 9883     207003         0          70   OnCurb  Stump    NaN       NaN
# 11342    206819         0         140   OnCurb  Stump    NaN       NaN
# 22452    228273         0          90   OnCurb  Stump    NaN       NaN
# ...         ...       ...         ...      ...    ...    ...       ...
# 611154   116605         0          77   OnCurb  Stump    NaN       NaN
# 626442    97902         0          66   OnCurb  Stump    NaN       NaN
# 645994   135904         0          65   OnCurb  Stump    NaN       NaN
# 649174   154188         0          65   OnCurb  Stump    NaN       NaN
# 653066   154190         0          80   OnCurb  Stump    NaN       NaN
#
#        steward sidewalk problems root_stone root_grate root_other trunk_wire  \
# ...

# %%
outlier_trees.plot(kind="scatter",x="tree_id",y="stump_diam",figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='tree_id', ylabel='stump_diam'>

# %%
name=tree_census_subset["spc_latin"].value_counts()
name
# Out:
# Platanus x acerifolia                 87014
# Gleditsia triacanthos var. inermis    64264
# Pyrus calleryana                      58931
# Quercus palustris                     53185
# Acer platanoides                      34189
#                                       ...
# Pinus nigra                              37
# Pinus rigida                             33
# Maclura pomifera                         29
# Pinus sylvestris                         25
# Pinus virginiana                         10
# Name: spc_latin, Length: 132, dtype: int64

# %%
name.plot(kind="bar",figsize=(20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Observations
# * from plot it can be seen that there are some trees which are more in number.
# * Platanus x acerifolia tree is the most common tree.

# %%
tree_census_subset["steward"].value_counts()
# Out:
# None       487823
# 1or2       143557
# 3or4        19183
# 4orMore      1610
# Name: steward, dtype: int64

# %%
tree_census_subset["sidewalk"].value_counts()
# Out:
# NoDamage    464978
# Damage      187194
# Name: sidewalk, dtype: int64

# %%
tree_census_subset["status"].value_counts()
# Out:
# Alive    652173
# Stump     17654
# Dead      13961
# Name: status, dtype: int64

# %%
stump_trees=tree_census_subset[tree_census_subset["status"]=="Stump"]
stump_trees
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health spc_latin  \
# 37       211205         0          16   OnCurb  Stump    NaN       NaN
# 239      203597         0          15   OnCurb  Stump    NaN       NaN
# 641      179766         0          30   OnCurb  Stump    NaN       NaN
# 644      180619         0          10   OnCurb  Stump    NaN       NaN
# 646      208828         0          15   OnCurb  Stump    NaN       NaN
# ...         ...       ...         ...      ...    ...    ...       ...
# 683348   152836         0          13   OnCurb  Stump    NaN       NaN
# 683686   191219         0          25   OnCurb  Stump    NaN       NaN
# 683695   170888         0           5   OnCurb  Stump    NaN       NaN
# 683697   177922         0          17   OnCurb  Stump    NaN       NaN
# 683699   172660         0           4   OnCurb  Stump    NaN       NaN
#
#        steward sidewalk problems root_stone root_grate root_other trunk_wire  \
# ...

# %%
dead_trees=tree_census_subset[tree_census_subset["status"]=="Dead"]
dead_trees
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health spc_latin  \
# 57       187807         0           0          OnCurb   Dead    NaN       NaN
# 196      208322        10           0          OnCurb   Dead    NaN       NaN
# 209      209058         6           0          OnCurb   Dead    NaN       NaN
# 266      210544         6           0          OnCurb   Dead    NaN       NaN
# 285      188609         9           0          OnCurb   Dead    NaN       NaN
# ...         ...       ...         ...             ...    ...    ...       ...
# 682816   184342        11           0          OnCurb   Dead    NaN       NaN
# 682823   155430         2           0          OnCurb   Dead    NaN       NaN
# 683346   156566        10           0          OnCurb   Dead    NaN       NaN
# 683693   156162         3           0  OffsetFromCurb   Dead    NaN       NaN
# 683698   193791         3           0          OnCurb   Dead    NaN       NaN
#
# ...

# %% [markdown]
# ### Observations
# * there are total of 31,615 trees which are either dead or stump.
# * it can be observed that there are similar number of NaN values as number of dead or stump tress.

# %%
problems_tree = tree_census_subset[['root_stone',
       'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
       'brch_light', 'brch_shoe', 'brch_other']]
problems_tree
# Out:
#        root_stone root_grate root_other trunk_wire trnk_light trnk_other  \
# 0              No         No         No         No         No         No
# 1             Yes         No         No         No         No         No
# 2              No         No         No         No         No         No
# 3             Yes         No         No         No         No         No
# 4             Yes         No         No         No         No         No
# ...           ...        ...        ...        ...        ...        ...
# 683783         No         No         No         No         No         No
# 683784         No         No         No         No         No         No
# 683785         No         No         No         No         No         No
# 683786         No         No         No         No         No         No
# 683787         No         No         No         No         No         No
#
#        brch_light brch_shoe brch_other
# 0              No        No         No
# ...

# %%
problems_tree.apply(pd.Series.value_counts)  #to check number of yes and No
# Out:
#      root_stone  root_grate  root_other  trunk_wire  trnk_light  trnk_other  \
# No       543789      680252      653466      670514      682757      651215
# Yes      139999        3536       30322       13274        1031       32573
#
#      brch_light  brch_shoe  brch_other
# No       621423     683377      659433
# Yes       62365        411       24355

# %% [markdown]
# ### Observations
# * root_stone problem is more.

# %% [markdown]
# ### For dead or stump trees health,steward,sidewalk,problems are not applicable,so changing those NaN with Not Applicable.

# %%
mask=((tree_census_subset["status"]=="Stump")|(tree_census_subset["status"]=="Dead"))

# %%
tree_census_subset.loc[mask] = tree_census_subset.loc[mask].fillna("Not Applicable")
# Out:
# /Users/shashidharpattar/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1717: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, v)

# %%
tree_census_subset[tree_census_subset["status"]=="Stump"]
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status          health  \
# 37       211205         0          16   OnCurb  Stump  Not Applicable
# 239      203597         0          15   OnCurb  Stump  Not Applicable
# 641      179766         0          30   OnCurb  Stump  Not Applicable
# 644      180619         0          10   OnCurb  Stump  Not Applicable
# 646      208828         0          15   OnCurb  Stump  Not Applicable
# ...         ...       ...         ...      ...    ...             ...
# 683348   152836         0          13   OnCurb  Stump  Not Applicable
# 683686   191219         0          25   OnCurb  Stump  Not Applicable
# 683695   170888         0           5   OnCurb  Stump  Not Applicable
# 683697   177922         0          17   OnCurb  Stump  Not Applicable
# 683699   172660         0           4   OnCurb  Stump  Not Applicable
#
#              spc_latin         steward        sidewalk        problems  \
# ...

# %%
tree_census_subset.isna().sum()
# Out:
# tree_id        0
# tree_dbh       0
# stump_diam     0
# curb_loc       0
# status         0
# health         1
# spc_latin      5
# steward        0
# sidewalk       1
# problems      49
# root_stone     0
# root_grate     0
# root_other     0
# trunk_wire     0
# trnk_light     0
# trnk_other     0
# brch_light     0
# brch_shoe      0
# brch_other     0
# dtype: int64

# %%
tree_census_subset.isna().sum()
# Out:
# tree_id        0
# tree_dbh       0
# stump_diam     0
# curb_loc       0
# status         0
# health         1
# spc_latin      5
# steward        0
# sidewalk       1
# problems      49
# root_stone     0
# root_grate     0
# root_other     0
# trunk_wire     0
# trnk_light     0
# trnk_other     0
# brch_light     0
# brch_shoe      0
# brch_other     0
# dtype: int64

# %%
tree_census_subset[tree_census_subset["health"].isna()]
# Out:
#        tree_id  tree_dbh  stump_diam curb_loc status health  \
# 32889   245041        16           0   OnCurb  Alive    NaN
#
#                     spc_latin steward sidewalk problems root_stone root_grate  \
# 32889  Fraxinus pennsylvanica    None   Damage     None         No         No
#
#       root_other trunk_wire trnk_light trnk_other brch_light brch_shoe  \
# 32889         No         No         No         No         No        No
#
#       brch_other
# 32889         No

# %%
tree_census_subset[tree_census_subset["spc_latin"].isna()]
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health spc_latin  \
# 356613   562532         4           0   OnCurb  Alive   Good       NaN
# 427541   630814        11           0   OnCurb  Alive   Poor       NaN
# 431417   651014        40           0   OnCurb  Alive   Good       NaN
# 608632    47941         5           0   OnCurb  Alive   Good       NaN
# 656960   150745         3           0   OnCurb  Alive   Good       NaN
#
#        steward  sidewalk problems root_stone root_grate root_other trunk_wire  \
# 356613    1or2  NoDamage   Stones        Yes         No         No         No
# 427541    None    Damage      NaN         No         No         No         No
# 431417    None    Damage   Stones        Yes         No         No         No
# 608632    1or2  NoDamage     None         No         No         No         No
# 656960    1or2    Damage     None         No         No         No         No
#
#        trnk_light trnk_other brch_light brch_shoe brch_other
# ...

# %%
tree_census_subset["sidewalk"].value_counts()
# Out:
# NoDamage          464978
# Damage            187194
# Not Applicable     31615
# Name: sidewalk, dtype: int64

# %%
tree_census_subset["problems"].value_counts()
# Out:
# None                                                                     426280
# Stones                                                                    95673
# Not Applicable                                                            31615
# BranchLights                                                              29452
# Stones,BranchLights                                                       17808
#                                                                           ...
# MetalGrates,RootOther,TrunkLights,BranchLights                                1
# Stones,RootOther,WiresRope,TrunkLights,BranchLights,BranchOther               1
# MetalGrates,RootOther,WiresRope,TrunkLights,BranchLights,BranchOther          1
# MetalGrates,RootOther,TrunkLights,TrunkOther,BranchLights,BranchOther         1
# MetalGrates,TrunkOther,BranchLights,BranchOther                               1
# Name: problems, Length: 233, dtype: int64

# %% [markdown]
# ### Observations
# * filling remaining NaN with maximum occuring value in that column.

# %%
tree_census_subset["health"].fillna("Good",inplace=True)
tree_census_subset["spc_latin"].fillna("Not Recorded",inplace=True)
tree_census_subset["sidewalk"].fillna("NoDamage",inplace=True)
tree_census_subset["problems"].fillna("None",inplace=True)
# Out:
# /Users/shashidharpattar/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py:4523: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,

# %%
tree_census_subset.isna().sum()
# Out:
# tree_id       0
# tree_dbh      0
# stump_diam    0
# curb_loc      0
# status        0
# health        0
# spc_latin     0
# steward       0
# sidewalk      0
# problems      0
# root_stone    0
# root_grate    0
# root_other    0
# trunk_wire    0
# trnk_light    0
# trnk_other    0
# brch_light    0
# brch_shoe     0
# brch_other    0
# dtype: int64

# %% [markdown]
# * No missing values.

# %% [markdown]
# ### Outlier Corrections
# #### Now for outliers in tree diameter column lets impute 25th percentile value and 75th percentile value of that particular species for very low diameter and very high diameter respectively.

# %%
tree_census_subset_alive =tree_census_subset[tree_census_subset["status"]=="Alive"]

# %%
alive_tree_dia=tree_census_subset_alive.groupby("spc_latin")["tree_dbh"].describe().reset_index()[["spc_latin","25%","75%"]]
alive_tree_dia
# Out:
#              spc_latin  25%   75%
# 0                 Acer  7.0  15.0
# 1    Acer buergerianum  5.0  10.0
# 2       Acer campestre  4.0   9.0
# 3         Acer ginnala  4.0  10.0
# 4         Acer griseum  2.0   3.0
# ..                 ...  ...   ...
# 128   Tsuga canadensis  2.0   7.0
# 129    Ulmus americana  4.0  17.0
# 130   Ulmus parvifolia  3.0  10.0
# 131       Ulmus pumila  4.0  17.0
# 132    Zelkova serrata  4.0  11.0
#
# [133 rows x 3 columns]

# %%
tree_census_subset_alive=tree_census_subset_alive.merge(alive_tree_dia,on="spc_latin",how="left")

# %%
tree_census_subset_alive
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683         3           0   OnCurb  Alive   Fair
# 1        200540        21           0   OnCurb  Alive   Fair
# 2        204026         3           0   OnCurb  Alive   Good
# 3        204337        10           0   OnCurb  Alive   Good
# 4        189565        21           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 652168   155433        25           0   OnCurb  Alive   Good
# 652169   183795         7           0   OnCurb  Alive   Good
# 652170   166161        12           0   OnCurb  Alive   Good
# 652171   184028         9           0   OnCurb  Alive   Good
# 652172   200607        23           0   OnCurb  Alive   Fair
#
#                                  spc_latin steward  sidewalk problems  \
# 0                              Acer rubrum    None  NoDamage     None
# 1                        Quercus palustris    None    Damage   Stones
# ...

# %%
mask  = tree_census_subset_alive["tree_dbh"]<tree_census_subset_alive["25%"]
tree_census_subset_alive.loc[mask,"tree_dbh"]=tree_census_subset_alive["25%"]


mask  = tree_census_subset_alive["tree_dbh"]>tree_census_subset_alive["75%"]
tree_census_subset_alive.loc[mask,"tree_dbh"]=tree_census_subset_alive["75%"]

# %%
tree_census_subset_alive
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683       5.0           0   OnCurb  Alive   Fair
# 1        200540      21.0           0   OnCurb  Alive   Fair
# 2        204026       6.0           0   OnCurb  Alive   Good
# 3        204337      10.0           0   OnCurb  Alive   Good
# 4        189565      12.0           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 652168   155433      24.0           0   OnCurb  Alive   Good
# 652169   183795       5.0           0   OnCurb  Alive   Good
# 652170   166161      12.0           0   OnCurb  Alive   Good
# 652171   184028       9.0           0   OnCurb  Alive   Good
# 652172   200607      14.0           0   OnCurb  Alive   Fair
#
#                                  spc_latin steward  sidewalk problems  \
# 0                              Acer rubrum    None  NoDamage     None
# 1                        Quercus palustris    None    Damage   Stones
# ...
